# %% [markdown]
# # Time Series Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style("whitegrid",  {"grid.linestyle": ":"})

# %%
ts = pd.read_csv('Gold_Yearly.csv')

# %%
ts.head()
# Out:
#    Year  Average\nClosing Price  Year Open  Year High  Year Low  Year Close  \
# 0  1969                   41.10      41.80      43.75     35.00       35.21
# 1  1970                   35.96      35.13      39.19     34.78       37.38
# 2  1971                   40.80      37.33      43.90     37.33       43.50
# 3  1972                   58.17      43.73      70.00     43.73       64.70
# 4  1973                   97.12      64.99     127.00     64.10      112.25
#
#    Annual\n% Change
# 0           -0.1607
# 1            0.0616
# 2            0.1637
# 3            0.4874
# 4            0.7349

# %%
#Renaming specific columns
ts = ts.rename(columns={'Average\nClosing Price': 'Avg Closing Price',
                       'Annual\n% Change':'Annual Percentage Change'})

# %%
ts.columns
# Out:
# Index(['Year', 'Avg Closing Price', 'Year Open', 'Year High', 'Year Low',
#        'Year Close', 'Annual Percentage Change'],
#       dtype='object')

# %% [markdown]
# ## Setting index to year column

# %%
ts = ts.set_index('Year')

# %%
ts.index
# Out:
# Int64Index([1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#             1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#             1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#             2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
#            dtype='int64', name='Year')

# %%
#Defining a function
def plotTS(x,y,title, xlabel, ylabel):
    fig, ax = plt.subplots(figsize=(10,8))
    
    ax.plot(x, y)
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    
    #Plotting
    plt.show()
    
plotTS(ts.index, ts['Avg Closing Price'],'Historical Closing Avg Price of Gold', 'Year','Price (USD)')

# %%
plotTS(ts.index, ts['Annual Percentage Change'],'Historical Yearly Percentage Change of the Price of Gold', 'Year', 'Percent Change')

# %% [markdown]
# ## Observations:
# Since 1969, the price of gold, a store of value, has seen exponential price growth. Today, the price is at $1,799.00, which is an increase of  4277.13%. Additionally, the price saw a significant increase in price entering the 1980's and 2010's, signaling, more than likely, a bull run.
